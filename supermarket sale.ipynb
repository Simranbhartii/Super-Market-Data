# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DEB887'>Super Market Exploratory Data Analysis</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">

# %% [markdown]
# ![lanes-shelves-with-goods-products-inside-supermarket-variety-preserves-pasta-shelves-full-tidy_123827-27553.avif](attachment:lanes-shelves-with-goods-products-inside-supermarket-variety-preserves-pasta-shelves-full-tidy_123827-27553.avif)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# GOAL OF PROJECT :
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# source of data kaggle:
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# work flow :
# </p>
# </div>

# %% [markdown]
# - step 1: importing the rquired libraries
# - step 2: loadiing the datasets
# - step 3: basic understanding of data
# - step 4: preprocesing

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# import library:
# </p>
# </div>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Loading the data set :
# </p>
# </div>

# %%
df=pd.read_csv("C:\\Users\\ritik\\Downloads\\data sets-20240403T102256Z-001\\data sets\\supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# BASIC UNDERSTANDING OF DATA:
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:green;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# PREVIEW OF DATA:
# </p>
# </div>

# %%
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 184  586-25-0848      A     Yangon        Normal  Female
# 704  640-48-5028      B   Mandalay        Member  Female
# 136  700-81-1757      A     Yangon        Normal  Female
# 569  408-26-9866      C  Naypyitaw        Normal  Female
# 565  698-98-5964      A     Yangon        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 184       Sports and travel       12.34         7   4.3190   90.6990
# 704      Home and lifestyle       88.39         9  39.7755  835.2855
# 136  Electronic accessories       26.31         5   6.5775  138.1275
# 569       Sports and travel       73.98         7  25.8930  543.7530
# 565      Food and beverages       81.21        10  40.6050  852.7050
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 184   3/4/2019  11:19  Credit card   86.38                 4.761905
# ...

# %%
# cogs mtlb cost of good soul

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:yellow;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:blue;
#           font-size:120%;
#           text-align:center;">
# how big is the data :
# </p>
# </div>

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#        background-color:hotpink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:purple;
#           font-size:120%;
#           text-align:center;">
# fecting the columns :
# </p>
# </div>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ##### - Column Description
#
# - Invoice id: Computer generated sales slip invoice identification number
#
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# - City: Location of supercenters
#
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# - Gender: Gender type of customer
#
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in $
#
# - Quantity: Number of products purchased by customer
#
# - Tax: 5% tax fee for customer buying
#
# - Total: Total price including tax
#
# - Date: Date of purchase (Record available from January 2019 to March 2019)
#
# - Time: Purchase time (10am to 9pm)
#
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# - COGS: Cost of goods sold
#
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
#
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# -  obsevation: from above output, all columns are in appropriate type except date and time so we need to convert into datetome for better analysis
# - and also the columns invoice id is seems irrelavant wrt to EDA so we will drop it later

# %% [markdown]
# # basic information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:red;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:yellow;
#           font-size:120%;
#           text-align:center;">
# preprocessing :
# </p>
# </div>

# %%
df.isnull().sum().to_frame().rename(columns={0:"missiing value count"}).T
# Out:
#                       Invoice ID  Branch  City  Customer type  Gender  \
# missiing value count           0       0     0              0       0
#
#                       Product line  Unit price  Quantity  Tax 5%  Total  Date  \
# missiing value count             0           0         0       0      0     0
#
#                       Time  Payment  cogs  gross margin percentage  \
# missiing value count     0        0     0                        0
#
#                       gross income  Rating
# missiing value count             0       0

# %%
# there is no missing value in data

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:blue;
#           font-size:120%;
#           text-align:center;">
# detecting the incinsistency :
# </p>
# </div>

# %%
df_obj=df.select_dtypes(include="object")
df_obj
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line       Date   Time      Payment
# 0         Health and beauty   1/5/2019  13:08      Ewallet
# 1    Electronic accessories   3/8/2019  10:29         Cash
# 2        Home and lifestyle   3/3/2019  13:23  Credit card
# ...

# %%
for i in df_obj.columns[1:]:
    print(i,"-----------",df[i].unique(),"has",df[i].nunique(),"unique values","\n\n")
# Out:
# Branch ----------- ['A' 'C' 'B'] has 3 unique values
#
#
# City ----------- ['Yangon' 'Naypyitaw' 'Mandalay'] has 3 unique values
#
#
# Customer type ----------- ['Member' 'Normal'] has 2 unique values
#
#
# Gender ----------- ['Female' 'Male'] has 2 unique values
#
#
# Product line ----------- ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories'] has 6 unique values
#
#
# Date ----------- ['1/5/2019' '3/8/2019' '3/3/2019' '1/27/2019' '2/8/2019' '3/25/2019'
#  '2/25/2019' '2/24/2019' '1/10/2019' '2/20/2019' '2/6/2019' '3/9/2019'
#  '2/12/2019' '2/7/2019' '3/29/2019' '1/15/2019' '3/11/2019' '1/1/2019'
#  '1/21/2019' '3/5/2019' '3/15/2019' '2/17/2019' '3/2/2019' '3/22/2019'
#  '3/10/2019' '1/25/2019' '1/28/2019' '1/7/2019' '3/23/2019' '1/17/2019'
#  '2/2/2019' '3/4/2019' '3/16/2019' '2/27/2019' '2/10/2019' '3/19/2019'
#  '2/3/2019' '3/7/2019' '2/28/2019' '3/27/2019' '1/20/2019' '3/12/2019'
# ...

# %%
df_numeric=df.select_dtypes(exclude="object")

# %%
df_numeric
# Out:
#      Unit price  Quantity   Tax 5%      Total    cogs  \
# 0         74.69         7  26.1415   548.9715  522.83
# 1         15.28         5   3.8200    80.2200   76.40
# 2         46.33         7  16.2155   340.5255  324.31
# 3         58.22         8  23.2880   489.0480  465.76
# 4         86.31         7  30.2085   634.3785  604.17
# ..          ...       ...      ...        ...     ...
# 995       40.35         1   2.0175    42.3675   40.35
# 996       97.38        10  48.6900  1022.4900  973.80
# 997       31.84         1   1.5920    33.4320   31.84
# 998       65.82         1   3.2910    69.1110   65.82
# 999       88.34         7  30.9190   649.2990  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ...

# %%
for i in df_numeric:
    print(i,"------------------",df[i].unique(),"has",df[i].nunique(),"unique values","\n\n")
# Out:
# Unit price ------------------ [74.69 15.28 46.33 58.22 86.31 85.39 68.84 73.56 36.26 54.84 14.48 25.51
#  46.95 43.19 71.38 93.72 68.93 72.61 54.67 40.3  86.04 87.98 33.2  34.56
#  88.63 52.59 33.52 87.67 88.36 24.89 94.13 78.07 83.78 96.58 99.42 68.12
#  62.62 60.88 54.92 30.12 86.72 56.11 69.12 98.7  15.37 93.96 56.69 20.01
#  18.93 82.63 91.4  44.59 17.87 15.43 16.16 85.98 44.34 89.6  72.35 30.61
#  24.74 55.73 55.07 15.81 75.74 15.87 33.47 97.61 78.77 18.33 89.48 62.12
#  48.52 75.91 74.67 41.65 49.04 78.31 20.38 99.19 96.68 19.25 80.36 48.91
#  83.06 76.52 49.38 42.47 76.99 47.38 44.86 21.98 64.36 89.75 97.16 87.87
#  12.45 52.75 82.7  48.71 78.55 23.07 58.26 30.35 88.67 27.38 62.13 33.98
#  81.97 16.49 98.21 72.84 58.07 80.79 27.02 21.94 51.36 10.96 53.44 99.56
#  57.12 99.96 63.91 56.47 93.69 32.25 31.73 68.54 90.28 39.62 92.13 34.84
#  87.45 81.3  90.22 26.31 34.42 51.91 72.5  89.8  90.5  68.6  30.41 77.95
# ...

# %%
for col in df_numeric:
    for i in df[col]:
        if i<=0:
            print("invalid entry is present")

# %% [markdown]
# # detecting the duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# there is no duplicacy in data

# %% [markdown]
# # feature engineering column extraction

# %%
# feature hum column ke liye use kr rhe hai

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["Time"]=pd.to_datetime(df["Time"])
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\2384983477.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Time"]=pd.to_datetime(df["Time"])

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
from datetime import datetime as dt

# %%
df["month"]=df.Date.dt.month_name()
df["day_name"]=df.Date.dt.day_name()
df["day"]=df.Date.dt.day
df["year"]=df.Date.dt.year
df["Hour"]=df.Time.dt.hour

# %%
df.head(6)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
# 5  Electronic accessories       85.39         7  29.8865  627.6165  ...
#
# ...

# %% [markdown]
#  # since we are dlt the invoice id as it seems irelavant nd also we r dlt branch as each city maps single branch

# %%
df.drop(columns=["Invoice ID","Branch"],inplace=True)

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity   Tax 5%     Total       Date                Time  Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2024-05-08 13:08:00  Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2024-05-08 10:29:00     Cash
#
#      cogs  gross margin percentage  gross income  Rating    month  day_name  \
# 0  522.83                 4.761905       26.1415     9.1  January  Saturday
# 1   76.40                 4.761905        3.8200     9.6    March    Friday
#
#    day  year  Hour
# 0    5  2019    13
# 1    8  2019    10

# %% [markdown]
# # insights

# %%
df.describe().T
# Out:
#                           count                        mean  \
# Unit price               1000.0                    55.67213
# Quantity                 1000.0                        5.51
# Tax 5%                   1000.0                   15.379369
# Total                    1000.0                  322.966749
# Date                       1000  2019-02-14 00:05:45.600000
# Time                       1000  2024-05-08 15:24:41.880000
# cogs                     1000.0                   307.58738
# gross margin percentage  1000.0                    4.761905
# gross income             1000.0                   15.379369
# Rating                   1000.0                      6.9727
# day                      1000.0                      15.256
# year                     1000.0                      2019.0
# Hour                     1000.0                       14.91
#
#                                          min                  25%  \
# ...

# %%
df.describe().T[:-3].index
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
cols=df.describe(include=["int","float"]).T.index[:-3]

# %%
pos=1
plt.figure(figsize=(15,10))
for col in cols:
    plt.subplot(2,4,pos)
    sns.boxplot(x=col,data=df)
    plt.title(col)
    pos=pos+1

# %%
df_numeric.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...

# %%
plt.figure(figsize=(5,10))
sns.heatmap(df_numeric.corr(),annot=True,cmap="rainbow")
# Out:
# <Axes: >

# %% [markdown]
# # observation: sort of positive relation
# - we can see the outliers found to be a same so there is connection between so for this we check the co-relation

# %% [markdown]
# - observation: there is perfect positive relation found between total,gross income,tax5%,cogs,there is sort of positive relation  between total ,quantity, there is no correction between rating and quantity

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'month',
#        'day_name', 'day', 'year', 'Hour'],
#       dtype='object')

# %%
df.drop(columns=["Tax 5%","cogs","gross income","gross margin percentage"],inplace=True)

# %%
df.head(4)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2     Yangon        Normal    Male      Home and lifestyle       46.33
# 3     Yangon        Member    Male       Health and beauty       58.22
#
#    Quantity     Total       Date                Time      Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-05-08 13:08:00      Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-05-08 10:29:00         Cash     9.6
# 2         7  340.5255 2019-03-03 2024-05-08 13:23:00  Credit card     7.4
# 3         8  489.0480 2019-01-27 2024-05-08 20:33:00      Ewallet     8.4
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10
# 2    March    Sunday    3  2019    13
# 3  January    Sunday   27  2019    20

# %% [markdown]
# - since the main column is in data is **total** from business point of it so we do univarite analsis

# %%
plt.figure(figsize=(10,4),facecolor="pink")
plt.subplot(1,2,1)
sns.distplot(df["Total"])
plt.title("Total sale distribution",color="brown",fontsize=12)
plt.subplot(1,2,2)
sns.boxplot(df["Total"])
plt.title("outliers detection analysis",fontsize=12,color="brown")
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\973886135.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Total"])
# Text(0.5, 1.0, 'outliers detection analysis')

# %%
# obsevation: this is right scew and people buy some product and they are so expensive thats why outliers show 800-1000

# %% [markdown]
# # total and average sale of the company

# %%
df["Total"].agg(["mean","sum"])
# Out:
# mean       322.966749
# sum     322966.749000
# Name: Total, dtype: float64

# %% [markdown]
# - since the some product are expensive means they are considered as outliers so we find median since the above avg sale does give the genuine insights

# %% [markdown]
# # which city is found to be a over crowded

# %%
sns.countplot(x="City",data=df,palette="Set2")
plt.title("crowded city")
# Out:
# Text(0.5, 1.0, 'crowded city')

# %% [markdown]
# # bar plot for avg sale ek numeric ek catergory

# %% [markdown]
# # total sale and avg sale of each city

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.barplot(x="City",y="Total",data=df,palette="Set2")
plt.yticks([0,50,100,150,200,250,300,350],["0 $","50 $","100 $","150 $","200 $","250 $","300 $","350 $"])
plt.title("Average sale of each city ",fontsize=15,color="brown",fontweight="bold")
plt.subplot(1,2,2)
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="Set2")
plt.title("Total sale of each city ",fontsize=15,color="brown",fontweight="bold");

# %% [markdown]
# - peak rush not always proptional to business nayppyitaw give more business according to yangon
# - all give same profit but naypytaw little bit good for company

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity      Total       Date                Time      Payment  Rating  \
# ...

# %% [markdown]
# - since the naypyitaw is the hot selling city so we find the detail on any day

# %%
df_n=df[df["City"]=="Naypyitaw"]
df_n[df_n["Total"]==df_n["Total"].max()]
# Out:
#           City Customer type  Gender         Product line  Unit price  \
# 350  Naypyitaw        Member  Female  Fashion accessories        99.3
#
#      Quantity    Total       Date                Time      Payment  Rating  \
# 350        10  1042.65 2019-02-15 2024-05-08 14:53:00  Credit card     6.6
#
#         month day_name  day  year  Hour
# 350  February   Friday   15  2019    14

# %% [markdown]
# # find the lowest sale on neypyitaw on any day

# %%
df_n=df[df["City"]=="Naypyitaw"]
df_n[df_n["Total"]==df_n["Total"].min()]
# Out:
#           City Customer type Gender       Product line  Unit price  Quantity  \
# 822  Naypyitaw        Member   Male  Sports and travel       10.17         1
#
#        Total       Date                Time Payment  Rating     month  \
# 822  10.6785 2019-02-07 2024-05-08 14:15:00    Cash     5.9  February
#
#      day_name  day  year  Hour
# 822  Thursday    7  2019    14

# %% [markdown]
# # root cause analysis of hot selling city

# %%
sns.countplot(x="City",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
# create countplot and all member are same in each brnach

# %%
sns.barplot(x="City",y="Rating",data=df)
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %%
 # second factor is rating

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-05-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-05-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %% [markdown]
# - there is not a specific cause behind the hot selling branch / city this could be due to natural factor

# %%
# neypyitaw mein health and beauty hai lekin yha sale nhi hai iss type ka customer hi nhi hai

# %% [markdown]
# # sale trend of company over the three months

# %%
plt.figure(figsize=(15,5))
sns.relplot(x="Date",y="Total",data=df,kind="line",color="purple",estimator=sum,ci=False)
plt.xlabel("date")
plt.title(" Company Sale trend over the  3 months ",fontsize=10,color="red",fontweight="bold")
plt.xticks(rotation=90);
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\ritik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # sale trend of each supermarket city

# %%
df_n=df[df["City"]=="Naypyitaw"]
df_y=df[df["City"]=="Yangon"]
df_m=df[df["City"]=="Mandalay"]

# %%
df_m
# Out:
#          City Customer type  Gender            Product line  Unit price  \
# 9    Mandalay        Member  Female      Food and beverages       54.84
# 10   Mandalay        Member  Female     Fashion accessories       14.48
# 11   Mandalay        Member    Male  Electronic accessories       25.51
# 15   Mandalay        Member  Female       Sports and travel       93.72
# 19   Mandalay        Normal  Female      Home and lifestyle       40.30
# ..        ...           ...     ...                     ...         ...
# 987  Mandalay        Member    Male       Health and beauty       62.00
# 989  Mandalay        Member    Male       Health and beauty       75.37
# 991  Mandalay        Normal  Female       Sports and travel       76.60
# 993  Mandalay        Normal    Male     Fashion accessories       17.49
# 996  Mandalay        Normal  Female      Home and lifestyle       97.38
#
#      Quantity     Total       Date                Time      Payment  Rating  \
# ...

# %%
cities=[df_m,df_n,df_y]

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(14,5))
for city in cities:
    #print(city)
    plt.subplot(1,3,pos)
    sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False)
    plt.title(f"the trend of city {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3889521240.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False)
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3889521240.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False)
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3889521240.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False)

# %% [markdown]
# # find the highest business revenue month of the company

# %%
sns.barplot(x="month",y="Total",data=df,estimator=sum,palette="Set2");

# %% [markdown]
# # business revenue in percentage of each month

# %%
df.groupby(["month"])["Total"].agg(["sum"])

plt.pie(df.groupby(["month"])["Total"].agg(["sum"])["sum"],labels=df.groupby(["month"])["Total"].agg(["sum"]).index,autopct="%.2f%%",colors=["red","green","orange"])
plt.title("Hot selling Month of the company ",fontsize=12,color="Red",fontweight="bold");

# %% [markdown]
#  # find the highest business revenue of each city and also sell pattern

# %%
plt.figure(figsize=(15,4),facecolor="pink")
plt.subplot(1,2,1)
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="Set2",hue="month");
plt.title("Average sale of each city in each month ",fontsize=15,color="brown",fontweight="bold")
plt.subplot(1,2,2)
sns.boxplot(x="City",y="Total",data=df,palette="Set2",hue="month");
plt.title("sale pattern of each city in each month",fontsize=15,color="brown",fontweight="bold");

# %% [markdown]
# - customer visting trend of each brach/city at each month
# - hot selling day of the company;
# - hot selling day of each city;
# - find the total weekday/weekend sale company;
# - total wekday wekend each city and each month
# - total sale of weekend/weekday of each city/month
# - find the most polpulated product of city/company;
# - find the most revenue generating company;

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']#1]
pos=1
plt.figure(figsize=(14,5))
for city in cities:
    #print(city)
    plt.subplot(1,3,pos)
    sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False,hue="month")
    plt.title(f"the trend of city {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1

# %%
plt.figure(figsize=(15,9)) # hot selling day
sns.barplot(x="day",y="Total",data=df,estimator=sum,palette="Set2",hue="City")
plt.title("hot selling day for company")

# %%
plt.figure(figsize=(15,9)) #each branch nd city
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="Set2")
plt.title("hot selling day for company")

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']# hot sliing in each city
pos=1
plt.figure(figsize=(14,5))
for city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.lineplot(x="day",y="Total",data=city,estimator=sum,ci=False)
    plt.title(f"the hot selling day{city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3288177327.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="day",y="Total",data=city,estimator=sum,ci=False)
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3288177327.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="day",y="Total",data=city,estimator=sum,ci=False)
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3288177327.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="day",y="Total",data=city,estimator=sum,ci=False)

# %%
df["weekday/weeknd"]=df["day_name"].apply(lambda x: "weekend "if x=="Saturday" or x=="Sunday" else "weekday")# weekday/weekend

# %%
sns.barplot(x="weekday/weeknd",y="Total",data=df,estimator=sum,palette="pastel");# weekday/weekend

# %%
print(df[df["weekday/weekend"]=="weekday"]["Total"].sum().round(2)
# Out:
#   Cell In[64], line 1
#     print(df[df["weekday/weekend"]=="weekday"]["Total"].sum().round(2)
#                                                                       ^
# SyntaxError: incomplete input

# %%
# weekday/weekend 
df[df["weekday/weeknd"]=="weekend "]["Total"].sum().round(2)
# Out:
# 100578.7

# %%
plt.pie([222388.05,100578.7],labels=["weekday","weekend"],autopct="%.2f%%");# weekday/weekend

# %%
plt.figure(figsize=(10,4))# weekday/weekend 
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="pastel",hue="weekday/weeknd")
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity      Total       Date                Time      Payment  Rating  \
# ...

# %%
df.groupby(["City","month","weekday/weeknd"])["Total"].agg(["sum"])#6
# Out:
#                                           sum
# City      month    weekday/weeknd
# Mandalay  February weekday         25964.4525
#                    weekend          8459.8185
#           January  weekday         27634.8870
#                    weekend          9541.1715
#           March    weekday         20898.5805
#                    weekend         13698.7620
# Naypyitaw February weekday         21950.5020
#                    weekend         10984.4805
#           January  weekday         30470.0550
#                    weekend          9964.6260
#           March    weekday         23041.4310
#                    weekend         14157.6120
# Yangon    February weekday         20417.2395
#                    weekend          9442.8810
#           January  weekday         25736.4870
#                    weekend         12944.6415
#           March    weekday         26274.4125
#                    weekend         11384.7090

# %%
sns.barplot(x="day_name",y="Total",data=df,estimator=sum,palette="dark") #4
# Out:
# <Axes: xlabel='day_name', ylabel='Total'>

# %%
sns.countplot(x="Product line",data=df,palette="dark")
plt.xticks(rotation=90); #the most demanding product

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="City",data=df,hue="Product line",palette="Set2")
plt.xticks(rotation=90);# cityke according popular product

# %%
sns.barplot(x="Product line",y="Total",estimator=sum,data=df,palette="Set2")
plt.xticks(rotation=90);# most business profit is food and beverages

# %% [markdown]
# # hot selling price each product and city

# %%
plt.figure(figsize=(10,12))
sns.barplot(x="City",y="Total",estimator=sum,data=df,palette="Set2",hue="Product line",ci=None)
plt.xticks(rotation=90);
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3215709899.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="City",y="Total",estimator=sum,data=df,palette="Set2",hue="Product line",ci=None)

# %% [markdown]
# # find the city and month wise demand of each product

# %%
df.groupby(["City","month"])["Product line"].value_counts()
# Out:
# City       month     Product line
# Mandalay   February  Fashion accessories       24
#                      Sports and travel         19
#                      Electronic accessories    19
#                      Food and beverages        17
#                      Health and beauty         16
#                      Home and lifestyle        14
#            January   Sports and travel         23
#                      Fashion accessories       21
#                      Food and beverages        19
#                      Electronic accessories    18
#                      Health and beauty         16
#                      Home and lifestyle        14
#            March     Home and lifestyle        22
#                      Health and beauty         21
#                      Sports and travel         20
#                      Electronic accessories    18
#                      Fashion accessories       17
#                      Food and beverages        14
# ...

# %% [markdown]
#  # find the monthly sale of each product of all the branches

# %%
df.groupby(["City","Product line","month"])["Total"].sum()
# Out:
# City       Product line            month
# Mandalay   Electronic accessories  February     6686.2530
#                                    January      6699.7770
#                                    March        3665.4135
#            Fashion accessories     February     6137.1135
#                                    January      6112.5960
#                                    March        4163.6070
#            Food and beverages      February     5554.8150
#                                    January      6609.2775
#                                    March        3050.7960
#            Health and beauty       February     5856.4275
#                                    January      6399.8865
#                                    March        7724.3460
#            Home and lifestyle      February     4659.8475
#                                    January      4586.4420
#                                    March        8302.8750
# ...

# %% [markdown]
# # peak time/hour customer visit at supermarket

# %% [markdown]
# # customer visiting time

# %%
plt.figure(figsize=(17,9))
sns.relplot(x="Hour",y="Total",data=df,estimator=sum,kind="line",ci=None)
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\ritik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity      Total       Date                Time      Payment  Rating  \
# ...

# %% [markdown]
# # peak time of each city

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay'] #relplot work nhi krega kuki multiple plot hai
pos=1
plt.figure(figsize=(14,15))
for city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.lineplot(x="Hour",y="Total",data=city,estimator=sum,ci=False)
    plt.title(f" hourly sale trend of {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3380086079.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Hour",y="Total",data=city,estimator=sum,ci=False)
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3380086079.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Hour",y="Total",data=city,estimator=sum,ci=False)
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\3380086079.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Hour",y="Total",data=city,estimator=sum,ci=False)

# %%
city=['Yangon', 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(25,15))
for i in cities:
    plt.subplot(3,1,pos)
    sns.lineplot(x="Hour",y="Total",data=i,estimator=sum,ci=None,hue="Product line")
    plt.title(f"peak time of branch {city[pos-1]}")
    plt.xticks(list(range(10,21)))
    pos=pos+1
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\2419832011.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Hour",y="Total",data=i,estimator=sum,ci=None,hue="Product line")
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\2419832011.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Hour",y="Total",data=i,estimator=sum,ci=None,hue="Product line")
# C:\Users\ritik\AppData\Local\Temp\ipykernel_8060\2419832011.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Hour",y="Total",data=i,estimator=sum,ci=None,hue="Product line")

# %% [markdown]
# # find the total number of customer

# %%
print("total customers : ",df["Gender"].count())
sns.countplot(x="Gender",data=df)
# Out:
# total customers :  1000
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# # total male and female customers in each city

# %%
sns.countplot(x="City",data=df,hue="Gender")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
#  # who contributed most in each city

# %%
sns.barplot(x="City",y="Total",data=df,estimator=sum,hue="Gender")
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %% [markdown]
#  #  which type of customer visting most

# %%
sns.countplot(x="City",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# # from which customer type business revenue generating

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.pie(df_y["Payment"].value_counts().values,labels=df_y["Payment"].value_counts().index,autopct="%.2f%%")
plt.title("% of customers based on \nmode of payement of city yangon")
plt.subplot(1,3,2)
plt.pie(df_m["Payment"].value_counts().values,labels=df_m["Payment"].value_counts().index,autopct="%.2f%%")
plt.title("% of customers based on \n mode of payement of city mandalay")
plt.subplot(1,3,3)
plt.pie(df_n["Payment"].value_counts().values,labels=df_n["Payment"].value_counts().index,autopct="%.2f%%")
plt.title("% of customers based on\n mode of payement of city naypayitaw");

# %% [markdown]
# # rating

# %%
df["Rating"].agg(["max","min","mean"])
# Out:
# max     10.0000
# min      4.0000
# mean     6.9727
# Name: Rating, dtype: float64

# %% [markdown]
# # how many customer give 10 rating

# %%
print(len(df[df["Rating"]==10.0]), "customers had given 10 rating")
print((len(df[df["Rating"]==10.0])*100)/df["Rating"].count(),"% customers had given 10 rating")
# Out:
# 5 customers had given 10 rating
# 0.5 % customers had given 10 rating

# %% [markdown]
# # how many customer give 4 rating

# %%
print(len(df[df["Rating"]==4.0]), "customers had given 4 rating")
print((len(df[df["Rating"]==4.0])*100)/df["Rating"].count(),"% customers had given 10 rating")
# Out:
# 11 customers had given 4 rating
# 1.1 % customers had given 10 rating

# %% [markdown]
# # how many customer give 5 rating

# %%
print(len(df[df["Rating"]<=5.0]), "customers had given below rating")
print((len(df[df["Rating"]<=5.0])*100)/df["Rating"].count(),"% customers had given below 5 rating")
# Out:
# 174 customers had given below rating
# 17.4 % customers had given below 5 rating

# %% [markdown]
# # each city rating

# %%
df.groupby(["City","Product line"])["Rating"].agg(["max","min","mean"])
# Out:
#                                    max  min      mean
# City      Product line
# Mandalay  Electronic accessories  10.0  4.0  7.116364
#           Fashion accessories      9.9  4.1  6.722581
#           Food and beverages       9.9  4.0  6.994000
#           Health and beauty        9.9  4.0  7.100000
#           Home and lifestyle       9.8  4.1  6.516000
#           Sports and travel       10.0  4.1  6.509677
# Naypyitaw Electronic accessories   9.8  4.1  6.747273
#           Fashion accessories      9.9  4.0  7.440000
#           Food and beverages       9.9  4.0  7.080303
#           Health and beauty        9.9  4.1  6.998077
#           Home and lifestyle       9.8  4.3  7.060000
#           Sports and travel       10.0  4.0  7.028889
# Yangon    Electronic accessories   9.9  4.3  6.911667
#           Fashion accessories      9.9  4.0  6.878431
#           Food and beverages       9.9  4.0  7.253448
#           Health and beauty       10.0  4.2  6.900000
# ...
